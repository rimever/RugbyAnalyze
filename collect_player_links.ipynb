# %%
import urllib.request
import bs4
# ESPNのニュージーランドの選手一覧ページにアクセスします。
url = 'http://en.espn.co.uk/newzealand/rugby/player/caps.html?team=8'
soup = bs4.BeautifulSoup(urllib.request.urlopen(url).read(), "lxml")
print(str(soup))
# Out:
# <!DOCTYPE html>
# <!-- hostname: web003, country: gb, cluster: uk, created: 2018-11-11 06:40:22 --><html xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <script type="text/javascript">var _sf_startpt=(new Date()).getTime()</script>
# <title>Rugby Union | New Zealand Caps | ESPN Scrum</title>
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
# <meta content="ESPN, ESPNscrum, ESPN rugby, scrum, rugby, news, results, rugby world cup, rugby union, rugby, rugby rules, rugby history, rugby photos, rugby pictures, live rugby scores, rugby tickets" name="keywords"/>
# <meta content="Scrum.com's coverage of the New Zealand rugby team and New Zealand club rugby. Live scores, points table and the latest news and features." name="description"/>
# <meta content="https://www.facebook.com/ESPNScrum" property="article:publisher"/>
# <!-- FB Tags starts -->
# <meta content="136690983034347" property="fb:app_id"/>
# <meta content="ESPN scrum" property="og:site_name"/>
# <!-- Load GPT config -->
# <!-- Load GPT JavaScript library used by DFP -->
# <script type="text/javascript">
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#   (function() {
#     var gads = document.createElement("script");
#     gads.async = true;
#     gads.type = "text/javascript";
#     var useSSL = "https:" == document.location.protocol;
#     gads.src = (useSSL ? "https:" : "http:") + "//www.googletagservices.com/tag/js/gpt.js";
#     var node =document.getElementsByTagName("script")[0];
#     node.parentNode.insertBefore(gads, node);
#    })();
# </script>
# <script src="http://a.espncdn.com/combiner/c?js=swfobject/2.2/swfobject.js?minify=false" type="text/javascript"></script>
# <script src="http://a.espncdn.com/combiner/c?js=plugins/jquery.pubsub.r5.js"></script>
# <!-- Style of debug GPT config -->
# <style>
# .espni-ad-slot{line-height: 0;}
# pre.gpt-debug{padding: 10px; background: burlywood;}
# </style>
# <!-- End Style -->
# <script type="text/javascript"> var ad_setting = {"adtar":"","kvbrand":"newzealand","kvcluster":"uk","kvnavtype":"","kvpt":"index","kvsite":"","networkid":"6444","path":"/6444/espn.uk/scrum/players"}; var __GPTenabled = true; </script>
# <link href="http://www.espnscrum.com/scrum/rugby/player/caps.html?team=8" rel="canonical"/>
# <!-- FB Tags ends -->
# <!--[if IE 9]>
# <script language="javascript" type="text/javascript">
# function fnCreateJumpList(iScenario) {
# fnClearJumpList();
# window.external.msSiteModeCreateJumpList("Quick Links")
# window.external.msSiteModeAddJumpListItem('ESPN Scrum Shop', 'http://www.espnscrum.com/scrum/rugby/url/243115.html', '/favicon.ico');
# window.external.msSiteModeAddJumpListItem('Champions Cup', 'http://www.espnscrum.com/european-rugby-champions-cup-2014-15/rugby/series/224327.html', '/favicon.ico');
# window.external.msSiteModeAddJumpListItem('Challenge Cup', 'http://www.espnscrum.com/european-rugby-challenge-cup-2014-15/rugby/series/229203.html', '/favicon.ico');
# window.external.msSiteModeAddJumpListItem('Aviva Premiership', 'http://www.espnscrum.com/premiership-2014-15/rugby/series/231649.html', '/favicon.ico');
# window.external.msSiteModeAddJumpListItem('Rugby World Cup Pools', 'http://www.espnscrum.com/2015-rugby-world-cup/rugby/page/249451.html', '/favicon.ico');
# window.external.msSiteModeAddJumpListItem('Coming Soon: A New ESPN', 'http://www.espnscrum.com/scrum/rugby/url/260573.html', '/favicon.ico');
# window.external.msSiteModeShowJumpList();
# }
# function fnClearJumpList() {
# window.external.msSiteModeClearJumplist();
# }
# </script>
# <meta name="msapplication-task" content="name=News;action-uri=http://www.espnscrum.com/scrum/rugby/story/news.html;icon-uri=/favicon.ico"/>
# <meta name="msapplication-task" content="name=Live Scores;action-uri=http://www.espnscrum.com/scrum/rugby/match/scores/live.html;icon-uri=/favicon.ico"/>
# <meta name="msapplication-task" content="name=Features;action-uri=http://www.espnscrum.com/scrum/rugby/story/features.html;icon-uri=/favicon.ico"/>
# <meta name="msapplication-task" content="name=Photos;action-uri=http://www.espnscrum.com/scrum/rugby/image/index.html;icon-uri=/favicon.ico"/>
# <meta name="msapplication-task" content="name=Video;action-uri=http://www.espnscrum.com/scrum/rugby/video_audio/index.html;icon-uri=/favicon.ico"/>
# <meta name="msapplication-task" content="name=Stats;action-uri=http://www.espnscrum.com/statsguru/rugby/stats/index.html;icon-uri=/favicon.ico"/>
# <script language="javascript" type="text/javascript">
#         fnCreateJumpList(2);
# </script>
# <![endif]--> <link href="/favicon.ie9new.ico" rel="shortcut icon"/>
# <link href="/favicon.gif" rel="shortcut icon" type="image/gif"/>
# <link href="http://www.espnscrum.com/rss/rugby/story/feeds/0.rss" rel="alternate" title="Global rugby news RSS feed" type="application/rss+xml"/>
# <link href="http://www.espnscrum.com/rss/rugby/story/feeds/caps.rss" rel="alternate" title=" rugby news RSS feed" type="application/rss+xml"/>
# <!-- CSS FILES !-->
# <link href="http://www.espnscrum.com/navigation/css/production/scrum.generic.0.1.16.min.css" rel="stylesheet" type="text/css"/>
# <link href="http://www.espnscrum.com/navigation/scrum/global_new.css?1421748475" rel="stylesheet" type="text/css"/>
# <style>
#         body {background:none;}
#
#     </style>
# <!-- JS FILES !-->
# <script language="javascript" src="http://www.espnscrum.com/navigation/scrum/jquery-1.7.2.min.js" type="text/javascript"></script>
# <script language="javascript" src="http://www.espnscrum.com/navigation/scripts/production/scrum.generic.0.1.16.min.js" type="text/javascript"></script>
# <script language="javascript" src="http://www.espnscrum.com/navigation/scrum/ajax.js" type="text/javascript"></script>
# <script language="javascript" src="http://www.espnscrum.com/navigation/scrum/default.js?1390556286" type="text/javascript"></script>
# <script language="javascript" src="http://www.espnscrum.com/navigation/scrum/mbox.js" type="text/javascript"></script>
# <script language="JavaScript">
# ord=Math.random()*10000000000000000;
# var ad_counter = 1;
# </script>
# <meta content="ESPNscrum" name="application-name"/>
# <meta content="#24b34b" name="msapplication-TileColor"/>
# <meta content="http://img.scrum.com/scrum/9f4a0d8e-10b1-48da-bc25-7a858090e29b.png" name="msapplication-TileImage"/>
# </head>
# <body class="espn_body" data-sport="all" style="width:100%;">
# <div id="fb-root"></div>
# <script>
#     window.fbAsyncInit = function() {
#         FB.init({
#             appId: '136690983034347',
#             status: true,
#             cookie: true,
#             xfbml: true,
#             oauth: true
#         });
#         FB.Event.subscribe('edge.create',
#             function(response) {
#                 refreshComment();
#             }
#         );
#     };
#       (function() {
#         var e = document.createElement('script');
#         e.type = 'text/javascript';
#         e.src = document.location.protocol +
#           '//connect.facebook.net/en_US/all.js';
#         e.async = true;
#         document.getElementById('fb-root').appendChild(e);
#       }());
#     </script>
# <link href="http://a.espncdn.com/combiner/c?css=fonts/bentonsans.css,fonts/bentonsansbold.css,fonts/bentonsanslight.css,fonts/bentonsansmedium.css" rel="stylesheet"/>
# <link href="http://a.espncdn.com/prod/styles/transitionalHeader/transitional-header.css" rel="stylesheet"/>
# <style>
#     .espn_body {background:rgb(238, 238, 238);}
#     .content_width {overflow:hidden;}
#     .page_area__content .content_width {background:#fff;border-right:5px solid #fff !important;}
#     .espn_transitional_banner {margin-top:103px;}
#
#             body.loading {width:100% !important;height:100% !important;margin:0 !important;}
#             #global-viewport #global-nav-secondary .global-nav-container > ul {float:none;clear:left;}
#             #global-nav-secondary .global-nav-container > ul > li > a {color:#000;}
#
#             #global-header .none {display:inline;}
#             #global-header .footer-links {clear:both;}
#             #global-header .tools {padding:0 !important;}
#             #global-header .container > h1 .progress {display:none !important;}
#
#             #global-nav > ul.espnuk-en > li.more-espn > div {width: 447px;}
#             #global-nav > ul > li.more-espn > div ul > li.external a:after {line-height: 100% !important;}
#             #global-nav > ul > li > div .conference .link-text {display:inline !important;}
#             #global-nav .nav-logo-wrap {min-width:25px !important;}
#             #global-nav ul.featured {background-color:#fff !important;width:auto !important;padding:0 !important;}
#             #global-nav div.footer-links {width:417px !important;}
#
#                 #global-viewport #global-nav-secondary .global-nav-container {max-width:1400px;}
#                 #global-viewport #global-nav > ul {padding-left:150px;max-width:1206px;padding-right:44px;}
#                 #global-viewport #global-nav-secondary .global-nav-container > ul {width:auto !important;}
#                 #global-nav-secondary .global-nav-container>ul>li.has-sub>div .link-text {display:block}
#
#
#     /* F1 Styles */
#     #ESPNF1Content .loc_bar {float:left;width:980px;margin:0px 0 0;padding:0 10px;}
#     #ESPNF1Content .loc_bar h2 {text-transform: uppercase;color: #fff;font-size: 14px;line-height:30px;}
#     #ESPNF1Content .loc_bar h2 span {font-size: 12px;text-transform: capitalize!important;}
#
# </style>
# <script type="text/javascript">
#     	var espn = espn || {};
#     	espn.nav = espn.nav || {};
#     	espn.nav.navId = 11665684;
#     	espn.nav.isFallback = false;
#     </script>
# <script src="http://a.espncdn.com/prod/scripts/transitionalHeader/espn.i18n-espnuk-en.js"></script>
# <script src="http://cdn.espn.com/core/format/modules/head/i18n?edition-host=espncricinfo.com&amp;type=ext&amp;site=espncricinfo&amp;region=us&amp;lang=en&amp;build=0.395.6"></script>
# <link crossorigin="" href="http://a.espncdn.com" rel="preconnect"/>
# <script src="http://a.espncdn.com/redesign/0.395.6/js/espn-head.js"></script>
# <script type="text/javascript">
#     window.espn_ui = window.espn_ui || {};
#     espn_ui.Helpers = espn_ui.Helpers || {};
#     espn_ui.Helpers.nav = espn_ui.Helpers.nav || {};
#     espn_ui.Helpers.nav.isNavExternal = true;
#     /*
#     if(window.location.hostname.indexOf('kilimanjaro')<0) {
#     window.espn = window.espn || {};
#     espn.i18n = espn.i18n || {};
#     espn.i18n.domain = window.location.hostname;
#     }
#     */
#     var espn = espn || {};
#     espn.i18n = espn.i18n || {};
#     if( espn.i18n.environment === "qa" ) {
#         espn.i18n.environment = "prod";
#     }
# </script>
# <script src="http://a.espncdn.com/redesign/0.395.6/js/espncricinfo-critical.js"></script>
# <script>
#
#   (function(){
#       var deferLoaded = false;
#       function loadDefer(){
#           if( !deferLoaded ){
#               var deferScripts = ['http://a.espncdn.com/redesign/0.395.6/js/espn-defer-low.js'];
#               for( var s = 0; s < deferScripts.length; s++ ){
#                   var script = document.createElement('script');
#                   script.src = deferScripts[s];
#                   document.getElementsByTagName('head')[0].appendChild(script);
#               }
#               deferLoaded = true;
#           }
#       }
#       if( window.espn.loadType === "loadEnd" && ( espn_ui.device.isMobile === true || espn_ui.device.isTablet === true ) ){
#           $( window ).load(function() {
#               setTimeout( loadDefer, 0 )
#           });
#           setTimeout( loadDefer, 5000 )
#       }else{
#           loadDefer();
#       }
#   })();
# </script>
# <script src="http://a.espncdn.com/redesign/0.395.6/external/release/js/nav-external.js"></script>
# <script>
#     espn_ui.onefeed =true;
#     espn_ui.externalRef = ""
#     $(window).load(function() {
#         $('#global-viewport img').each(function() {
#             if (!this.complete || typeof this.naturalWidth == "undefined" || this.naturalWidth == 0) {
#                 $(this).parent().remove();
#             }
#         });
#     });
# </script>
# <script>
#     if($.cookie('scoresLinkAlertCookie') !== "true"){
#         $(".scores-link-alert").removeClass("hidden");
#     }
#
#     $('#global-scoreboard-trigger').add('.scores-link-alert').on("click", function(){
#         // Cookie expiry time set to 1 year
#         $.cookie('scoresLinkAlertCookie', true, {expires: 365});
#         $(".scores-link-alert").remove();
#     })
# </script>
# <script type="text/javascript">
#         (function($){
#             if(!window.espn_ui.Helpers.links){
#                 window.espn_ui.Helpers.links = {};
#                 if(!window.espn_ui.Helpers.links.shouldAjax){
#                     window.espn_ui.Helpers.links.shouldAjax = function(){
#                         return 0;
#                     }
#                 }
#             }
#             $(document).ready(function(){
#                 var $oTempH1 = $('#logoClickOverride');
#                 if($oTempH1){
#                     $oTempH1.bind('click',function(){
#                         window.location.href = $oTempH1.attr('href');
#                     });
#                 }
#             })
#         })(jQuery);
#     </script>
# <div data-behavior="global_nav_condensed global_nav_full" id="global-viewport">
# <div data-behavior="global_header" id="header-wrapper">
# <!-- BEGIN: desktop nav -->
# <header class="espnuk-en" id="global-header">
# <div class="container">
# <a href="#" id="global-nav-mobile-trigger"><span>Menu</span></a><h1><a href="http://www.espn.co.uk" id="logoClickOverride" name="&amp;lpos=sitenavdefault&amp;lid=sitenav_main-logo">ESPN</a></h1>
# <ul class="tools">
# <li class="search" style="touch-action: pan-y; -webkit-user-drag: none; -webkit-tap-highlight-color: rgba(0, 0, 0, 0);">
# <a href="#" id="global-search-trigger">searchSportsTeamPlayers...</a>
# <div class="global-search" data-behavior="type_to_search" id="global-search">
# <input class="search-box" placeholder="Search Sports, Teams or Players..." type="text"/>
# <input class="btn-search" type="submit"/>
# </div>
# </li>
# </ul>
# </div>
# <nav data-loadtype="server" data-wayfindsport="" id="global-nav">
# <ul class="espnuk-en" itemscope="" itemtype="http://www.schema.org/SiteNavigationElement">
# <li class=" sports" itemprop="name">
# <a href="http://www.espn.co.uk/football/" itemprop="url">
# <span class="link-text">Football</span>
# <span class="link-text-short">Football</span>
# </a>
# <div><ul>
# <li class=" sports" itemprop="name">
# <a href="http://www.espn.co.uk/football/" itemprop="url">
# <span class="link-text">Home</span>
# <span class="link-text-short">Home</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="http://www.espn.co.uk/football/scoreboard" itemprop="url">
# <span class="link-text">Scores</span>
# <span class="link-text-short">Scores</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="http://www.espn.co.uk
src="http://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500/160.png&amp;w=50&amp;h=50"/></div>
# <a class="sprite-soccer-teams-25 sprite-25-team-160" data-teamid="160" href="http://www.espn.co.uk/football/team/_/id/160/psg" itemprop="url" name="PSG">
# <span class="link-text">PSG</span>
# <span class="link-text-short">PSG</span>
# </a>
# </li>
# </ul></div></li></ul></div>
# </li>
# <li class=" sports" itemprop="name">
# <a href="http://www.espn.co.uk/cricket/" itemprop="url">
# <span class="link-text">Cricket</span>
# <span class="link-text-short">Cricket</span>
# </a>
# <div><ul>
# <li class=" sports" itemprop="name">
# <a href="http://www.espn.co.uk/cricket/" itemprop="url">
# <span class="link-text">Home</span>
# <span class="link-text-short">Home</span>
# </a>
# </li>
# <li class="external sports" itemprop="name">
# <a href="http://www.espncricinfo.com/ci/engine/match/index.html?view=live" itemprop="url" target="_blank">
# <span class="link-text">Scores</span>
# <span class="link-text-short">Scores</span>
# </a>
# </li>
# <li class="external sports" itemprop="name">
# <a href="http://www.espncricinfo.com/ci/content/current/match/fixtures/index.html" itemprop="url" target="_blank">
# <span class="link-text">Fixtures &amp; Results</span>
# <span class="link-text-short">Fixtures &amp; Results</span>
# </a>
# </li>
# <li class="external sports" itemprop="name">
# <a href="http://www.espncricinfo.com/rankings/content/page/211271.html" itemprop="url" target="_blank">
# <span class="link-text">ICC Rankings</span>
# <span class="link-text-short">ICC Rankings</span>
# </a>
# </li>
# <li class="external sports" itemprop="name">
# <a href="http://www.espncricinfo.com/county-cricket-2015/content/current/series/786877.html" itemprop="url" target="_blank">
# <span class="link-text">County Cricket</span>
# <span class="link-text-short">County Cricket</span>
# </a>
# </li>
# <li class="external sports" itemprop="name">
# <a href="http://www.espncricinfo.com/ci/content/stats/index.html" itemprop="url" target="_blank">
# <span class="link-text">Stats</span>
# <span class="link-text-short">Stats</span>
# </a>
# </li>
# <li class="external sports" itemprop="name">
# <a href="http://www.espncricinfo.com/mobile/content/site/mobile/mobilehome.html" itemprop="url" target="_blank">
# <span class="link-text">ESPN Cricinfo App</span>
# <span class="link-text-short">ESPN Cricinfo App</span>
# </a>
# </li>
# </ul></div>
# </li>
# <li class="active sports" itemprop="name">
# <a href="http://www.espn.co.uk/rugby/" itemprop="url">
# <span class="link-text">Rugby</span>
# <span class="link-text-short">Rugby</span>
# </a>
# <div><ul>
# <li class=" sports" itemprop="name">
# <a href="http://www.espn.co.uk/rugby/" itemprop="url">
# <span class="link-text">Home</span>
# <span class="link-text-short">Home</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="http://www.espn.co.uk/rugby/scoreboard" itemprop="url">
# <span class="link-text">Scores</span>
# <span class="link-text-short">Scores</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="http://www.espn.co.uk/rugby/fixtures" itemprop="url">
# <span class="link-text">Fixtures &amp; Results</span>
# <span class="link-text-short">Fixtures &amp; Results</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="http://www.espn.co.uk/rugby/table/_/season/2015/league/164205" itemprop="url">
# <span class="link-text">Tables</span>
# <span class="link-text-short">Tables</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="//en.espn.co.uk/scrum/rugby/page/260507.html" itemprop="url">
# <span class="link-text">Tournaments</span>
# <span class="link-text-short">Tournaments</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="//en.espn.co.uk/scrum/rugby/page/260505.html" itemprop="url">
# <span class="link-text">Countries</span>
# <span class="link-text-short">Countries</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="//en.espn.co.uk/scrum/rugby/player/index.html" itemprop="url">
# <span class="link-text">Players</span>
# <span class="link-text-short">Players</span>
# </a>
# </li>
# <li class="external sports" itemprop="name">
# <a href="http://fantasyrugby.espn.co.uk" itemprop="url" target="_blank">
# <span class="link-text">Fantasy Rugby</span>
# <span class="link-text-short">Fantasy Rugby</span>
# </a>
# </li>
# </ul></div>
# </li>
# <li class=" sports" itemprop="name">
# <a href="http://www.espn.co.uk/f1/" itemprop="url">
# <span class="link-text">F1</span>
# <span class="link-text-short">F1</span>
# </a>
# <div><ul>
# <li class=" sports" itemprop="name">
# <a href="http://www.espn.co.uk/f1/" itemprop="url">
# <span class="link-text">Home</span>
# <span class="link-text-short">Home</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="//en.espn.co.uk/f1/motorsport/season/185539.html" itemprop="url">
# <span class="link-text">Calendar</span>
# <span class="link-text-short">Calendar</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="//en.espn.co.uk/f1/motorsport/season/185539.html?template=standings" itemprop="url">
# <span class="link-text">Standings</span>
# <span class="link-text-short">Standings</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="//en.espn.co.uk/f1/motorsport/race/index.html?season=2015" itemprop="url">
# <span class="link-text">Races</span>
# <span class="link-text-short">Races</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="//en.espn.co.uk/f1/motorsport/season/185539.html" itemprop="url">
# <span class="link-text">Results</span>
# <span class="link-text-short">Results</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="//en.espn.co.uk/f1/motorsport/team/index.html" itemprop="url">
# <span class="link-text">Teams</span>
# <span class="link-text-short">Teams</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="//en.espn.co.uk/f1/motorsport/driver/index.html" itemprop="url">
# <span class="link-text">Drivers</span>
# <span class="link-text-short">Drivers</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="//en.espn.co.uk/f1/motorsport/circuit/index.html?season=2015" itemprop="url">
# <span class="link-text">Circuits</span>
# <span class="link-text-short">Circuits</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="//en.espn.co.uk/f1/motorsport/season/index.html" itemprop="url">
# <span class="link-text">Stats &amp; Records</span>
# <span class="link-text-short">Stats &amp; Records</span>
# </a>
# </li>
# </ul></div>
# </li>
# <li class=" sports" itemprop="name">
# <a href="http://www.espn.co.uk/boxing/" itemprop="url">
# <span class="link-text">Boxing</span>
# <span class="link-text-short">Boxing</span>
# </a>
# <div><ul>
# <li class=" sports" itemprop="name">
# <a href="http://www.espn.co.uk/boxing/" itemprop="url">
# <span class="link-text">Home</span>
# <span class="link-text-short">Home</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="http://www.espn.co.uk/boxing/story/_/id/12508267/boxing-fight-schedule" itemprop="url">
# <span class="link-text">Schedule</span>
# <span class="link-text-short">Schedule</span>
# </a>
# </li>
# <li class="external sports" itemprop="name">
# <a href="http://sports.espn.go.com/sports/boxing/champions/" itemprop="url" target="_blank">
# <span class="link-text">Champions</span>
# <span class="link-text-short">Champions</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="http://espn.go.com/video/category?id=2491554" itemprop="url">
# <span class="link-text">Video</span>
# <span class="link-text-short">Video</span>
# </a>
# </li>
# </ul></div>
# </li>
# <li class=" sports" itemprop="name">
# <a href="http://www.espn.co.uk/nba/" itemprop="url">
# <span class="link-text">NBA</span>
# <span class="link-text-short">NBA</span>
# </a>
# <div><ul>
# <li class=" sports" itemprop="name">
# <a href="http://www.espn.co.uk/nba/" itemprop="url">
# <span class="link-text">Home</span>
# <span class="link-text-short">Home</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="http://www.espn.co.uk/nba/scoreboard" itemprop="url">
# <span class="link-text">Scores</span>
# <span class="link-text-short">Scores</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="http://sports.espn.go.com/nba/teams" itemprop="url">
# <span class="link-text">Teams</span>
# <span class="link-text-short">Teams</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="http://www.espn.co.uk/nba/schedule" itemprop="url">
# <span class="link-text">Schedule</span>
# <span class="link-text-short">Schedule</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="http://sports.espn.go.com/nba/statistics" itemprop="url">
# <span class="link-text">Stats</span>
# <span class="link-text-short">Stats</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="http://www.espn.co.uk/nba/standings" itemprop="url">
# <span class="link-text">Standings</span>
# <span class="link-text-short">Standings</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="http://sports.espn.go.com/nba/players" itemprop="url">
# <span class="link-text">Players</span>
# <span class="link-text-short">Players</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="http://sports.espn.go.com/nba/draft" itemprop="url">
# <span class="link-text">Draft</span>
# <span class="link-text-short">Draft</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="http://sports.espn.go.com/nba/theten" itemprop="url">
# <span class="link-text">The Ten</span>
# <span class="link-text-short">The Ten</span>
# </a>
# </li>
# </ul></div>
# </li>
# <li class=" none more" itemprop="name">
# <a href="//en.espn.co.uk" itemprop="url">
# <span class="link-text">...</span>
# <span class="link-text-short">...</span>
# </a>
# <div><ul class="split">
# <li class=" sports" itemprop="name">
# <a href="http://www.espn.co.uk/golf/" itemprop="url">
# <span class="link-text">Golf</span>
# <span class="link-text-short">Golf</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="http://www.espn.co.uk/tennis/" itemprop="url">
# <span class="link-text">Tennis</span>
# <span class="link-text-short">Tennis</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="http://www.espn.co.uk/olympics/" itemprop="url">
# <span class="link-text">Olympic Sports</span>
# <span class="link-text-short">Olympic Sports</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="http://www.espn.co.uk/athletics/" itemprop="url">
# <span class="link-text">Athletics</span>
# <span class="link-text-short">Athletics</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="http://www.espn.co.uk/horse-racing/" itemprop="url">
# <span class="link-text">Horse Racing</span>
# <span class="link-text-short">Horse Racing</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="http://www.espn.co.uk/snooker/" itemprop="url">
# <span class="link-text">Snooker</span>
# <span class="link-text-short">Snooker</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="http://www.espn.co.uk/cycling/" itemprop="url">
# <span class="link-text">Cycling</span>
# <span class="link-text-short">Cycling</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="http://www.espn.co.uk/darts/" itemprop="url">
# <span class="link-text">Darts</span>
# <span class="link-text-short">Darts</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="http://www.espn.co.uk/ufc/" itemprop="url">
# <span class="link-text">MMA</span>
# <span class="link-text-short">MMA</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="//en.espn.co.uk/poker/sport/site/367431.html" itemprop="url">
# <span class="link-text">Poker</span>
# <span class="link-text-short">Poker</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="http://www.espn.co.uk/nfl/" itemprop="url">
# <span class="link-text">NFL</span>
# <span class="link-text-short">NFL</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="http://www.espn.co.uk/mlb/" itemprop="url">
# <span class="link-text">MLB</span>
# <span class="link-text-short">MLB</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="http://www.espn.co.uk/nhl/" itemprop="url">
# <span class="link-text">NHL</span>
# <span class="link-text-short">NHL</span>
# </a>
# </li>
# <li class=" sports" itemprop="name">
# <a href="http://www.espn.co.uk/college-football/" itemprop="url">
# <span class="link-text">NCAAF</span>
# <span class="link-text-short">NCAAF</span>
# </a>
# </li>
# </ul></div>
# </li>
# <li class="pillar more-espn" itemprop="name">
# <a href="#" itemprop="url"><span class="link-text">More ESPN</span><span class="link-text-short">More ESPN</span></a>
# <div>
# <ul class="editions">
# <li class="none header-title" itemprop="name">
# <a data-class="header-title" href="#" itemprop="url"><span class="link-text"></span><span class="link-text-short"></span></a>
# <div><ul class="editions"><li class="label header-title" itemprop="name"><span><span class="link-text">International</span><span class="link-text-short">International</span></span></li><li class="external" itemprop="name"><a href="http://espn.go.com/" itemprop="url" name="&amp;lpos=sitenavdefault&amp;lid=sitenav_more_espnus" target="_blank"><span class="link-text">US</span><span class="link-text-short">US</span></a></li><li class="external" itemprop="name"><a href="http://www.espn.com.au/" itemprop="url" name="&amp;lpos=sitenavdefault&amp;lid=sitenav_more_espnaustralia" target="_blank"><span class="link-text">Australia</span><span class="link-text-short">Australia</span></a></li></ul>
# </div></li>
# </ul>
# <ul class="featured">
# <li class="none featured-links" itemprop="name">
# <a href="#" itemprop="url">
# <span class="link-text"></span>
# <span class="link-text-short"></span>
# </a>
# <div>
# <ul class="featured">
# <li class="label header-title" itemprop="name">
# <span>
# <span class="link-text">More from ESPN</span>
# <span class="link-text-short">More from ESPN</span>
# </span>
# </li>
# <li class="external" itemprop="name">
# <a href="http://www.espnplayer.com/espnplayer/console" itemprop="url" name="&amp;lpos=sitenavdefault&amp;lid=sitenav_more_espn+player" target="_blank">
# <span class="link-text">ESPN Player</span>
# <span class="link-text-short">ESPN Player</span>
# </a>
# </li>
# <li class="external logo cricinfo" itemprop="name">
# <a data-logo="cricinfo" href="http://www.espncricinfo.com/" itemprop="url" name="&amp;lpos=sitenavdefault&amp;lid=sitenav_more_espn+cricinfo" target="_blank">
# <span class="link-text">ESPN CricInfo</span>
# <span class="link-text-short">ESPN CricInfo</span>
# </a>
# </li>
# <li class="external logo fivethirtyeight" itemprop="name">
# <a data-logo="fivethirtyeight" href="http://www.fivethirtyeight.com/" itemprop="url" name="&amp;lpos=sitenavdefault&amp;lid=sitenav_more_fivethirtyeight" target="_blank">
# <span class="link-text">FiveThirtyEight</span>
# <span class="link-text-short">FiveThirtyEight</span>
# </a>
# </li>
# </ul>
# </div>
# </li>
# </ul>
# <div class="footer-links">
# <ul class="more-more pipes">
# <li itemprop="name"><a data-mobile="false" href="http://espn.az1.qualtrics.com/SE/?SID=SV_e5rTntMo8UAvBGJ" itemprop="url" name="&amp;lpos=sitenavdefault&amp;lid=sitenav_more_send+feedback"><span class="link-text">Send Feedback</span><span class="link-text-short">Send Feedback</span></a></li>
# <li itemprop="name"><a href="http://www.espn.co.uk/espn/sport/page/1363.html" itemprop="url" name="&amp;lpos=sitenavdefault&amp;lid=sitenav_more_about+us"><span class="link-text">About Us</span><span class="link-text-short">About Us</span></a></li>
# <li itemprop="name"><a href="http://disneyprivacycenter.com/" itemprop="url" name="&amp;lpos=sitenavdefault&amp;lid=sitenav_more_privacy+policy"><span class="link-text">Privacy Policy</span><span class="link-text-short">Privacy Policy</span></a></li>
# <li itemprop="name"><a href="http://disneytermsofuse.com/" itemprop="url" name="&amp;lpos=sitenavdefault&amp;lid=sitenav_more_terms+of+use"><span class="link-text">Terms of Use</span><span class="link-text-short">Terms of Use</span></a></li>
# <li itemprop="name"><a href="https://disneyprivacycenter.com/cookies-policy-translations/cookies-policy/" itemprop="url" name="&amp;lpos=sitenavdefault&amp;lid=sitenav_more_cookie+policy"><span class="link-text">Cookie Policy</span><span class="link-text-short">Cookie Policy</span></a></li>
# </ul>
# </div>
# <div class="footer-wrapper"><ul class="footer"><li class="footer label"><span class="link-text">© 2015 ESPN Internet Ventures. <a href="http://disneytermsofuse.com/" rel="nofollow">Terms of Use</a> and <a href="http://disneyprivacycenter.com/" rel="nofollow">Privacy Policy</a> are applicable to you.  All rights reserved. </span><span class="link-text-short">Footer</span></li></ul></div></div>
# </li>
# <li class="pillar fantasy" itemprop="name">
# <a href="http://fantasyrugby.espn.co.uk" itemprop="url" name="&amp;lpos=sitenavcustom&amp;lid=sitenav_fantasy"><span class="link-text">Fantasy</span><span class="link-text-short">Fantasy</span></a>
# <div>
# <ul>
# <li itemprop="name"><a href="http://fantasyrugby.espn.co.uk" itemprop="url" name="Rugby"><span class="link-text">Rugby</span><span class="link-text-short">Rugby</span></a></li>
# <li class="external" itemprop="name"><a href="http://fantasyrugby.espn.co.uk" itemprop="url" name="Fantasy Home" target="_blank"><span class="link-text">Fantasy Home</span><span class="link-text-short">Fantasy Home</span></a></li>
# <li itemprop="name"><a href="http://games.espn.go.com/premier-fantasy/2016/en_GB/" itemprop="url" name="Premier Fantasy"><span class="link-text">Premier Fantasy</span><span class="link-text-short">Premier Fantasy</span></a></li>
# <li itemprop="name"><a href="http://games.espn.go.com/champions-league-pickem/2015/en/" itemprop="url" name="Champions league Pick'Em"><span class="link-text">Champions league Pick'Em</span><span class="link-text-short">Champions league Pick'Em</span></a></li>
# <li itemprop="name"><a href="http://games.espn.go.com/frontpage/football" itemprop="url" name="American Football"><span class="link-text">American Football</span><span class="link-text-short">American Football</span></a></li>
# <li itemprop="name"><a href="http://games.espn.go.com/frontpage/baseball" itemprop="url" name="Baseball"><span class="link-text">Baseball</span><span class="link-text-short">Baseball</span></a></li>
# <li itemprop="name"><a href="http://games.espn.go.com/frontpage/basketball" itemprop="url" name="Basketball"><span class="link-text">Basketball</span><span class="link-text-short">Basketball</span></a></li>
# <li itemprop="name"><a href="http://games.espn.go.com/frontpage/hockey" itemprop="url" name="Hockey"><span class="link-text">Hockey</span><span class="link-text-short">Hockey</span></a></li>
# <li itemprop="name"><a href="http://streak.espn.go.com" itemprop="url" name="Streak for the cash"><span class="link-text">Streak for the cash</span><span class="link-text-short">Streak for the cash</span></a></li>
# <li itemprop="name"><a href="http://espn.go.com/free-online-games/" itemprop="url" name="ESPN Arcade"><span class="link-text">ESPN Arcade</span><span class="link-text-short">ESPN Arcade</span></a></li>
# </ul>
# <ul>
# <li class="teams fantasy" itemprop="name"></li>
# </ul>
# </div>
# </li>
# <li class="pillar watch" itemprop="name">
# <a href="http://espn.go.com/watchespn/index" itemprop="url" name="&amp;lpos=sitenavcustom&amp;lid=sitenav_watch"><span class="link-text">TV</span><span class="link-text-short">TV</span></a>
# <div>
# <ul>
# <li itemprop="name"><a href="/espn/sport/site/splash_new.html" itemprop="url" name="TV"><span class="link-text">TV</span><span class="link-text-short">TV</span></a></li>
# <li class="external" itemprop="name"><a href="http://www.espnplayer.com/espnplayer/console" itemprop="url" name="&amp;lpos=sitenavdefault&amp;lid=sitenav_tv_espn+player" target="_blank"><span class="link-text">ESPN Player</span><span class="link-text-short">ESPN Player</span></a></li>
# </ul>
# </div>
# </li>
# </ul></nav>
# <nav class="global-nav-secondary-soccer" data-behavior="mobile_tabs" id="global-nav-secondary">
# <div class="global-nav-container">
# <div class="sportbrand"><a href="#"><img class="imageLoaded" src="http://i.espn.co.uk/espnuk/logo-uk-scrum.png"/></a></div>
# <ul>
# <li class="sports" itemprop="name">
# <span class="positioning">
# <a href="http://www.espn.co.uk/rugby/" itemprop="url" name="">
# <span class="brand-logo icon-logo icon-rugby"></span>
# <span class="link-text">Rugby</span>
# <span class="link-text-short">Rugby</span>
# </a>
# </span>
# </li>
# <li class="sub " itemprop="name">
# <a href="http://www.espn.co.uk/rugby/" itemprop="url">
# <span class="link-text">Home</span>
# </a>
# </li>
# <li class="sub " itemprop="name">
# <a href="http://www.espn.co.uk/rugby/scoreboard" itemprop="url">
# <span class="link-text">Scores</span>
# </a>
# </li>
# <li class="has-sub" itemprop="name">
# <a href="http://www.espn.co.uk/rugby/fixtures" itemprop="url">
# <span class="link-text">Fixtures &amp; Results</span>
# </a>
# <div>
# <ul class="split">
# <li class="sub" itemprop="name">
# ...
# </tr>
# <tr>
# <td>862</td>
# <td><a href="/newzealand/rugby/player/265445.html"><b>Tyrel Lomax</b></a></td>
# <td>(P)</td>
# <td><a href="/newzealand/rugby/match/295097.html">v Japan Tokyo, 3 Nov 2018</a></td>
# </tr>
# </table>
# <p><b>Players are sorted by date of debut with those in the starting lineup before replacements, then alphabetically by surname and initials.</b></p>
# <p><b>Position indicates their starting position in the debut match, with replacements in brackets.</b></p>
# <br/>
# </div>
# </div>
# <div class="botom650"></div> <!-- END 650 AREA -->
# </div>
# <div id="scrumRhs">
# <h2 class="ESPNLiveTitle">Live Sports</h2>
# <div class="ESPNlive" id="ESPNlive">
# <p class="ESPNLiveCommsErr">Communication error please reload the page.</p>
# <ul class="ESPNLiveul">
# <li>
# <h2 class="espnFootball"><span class="liveArrow"></span>Football<span class="live-ico"></span></h2>
# <div class="ESPNLive_cont">
# <div class="ESPNLiveTab">
# <ul class="ESPNLiveTabs">
# <li><a class="ESPNLiveTabsOn" href="#ESPNLiveFootResults">Results</a></li>
# <li><a href="#ESPNLiveFoot">Today<span id="ESPNLiveFootNo"></span></a></li>
# <li><a href="#ESPNLiveFootFixt">Fixtures</a></li>
# </ul>
# <div class="ESPNLiveTabContent" id="ESPNLiveFootResults">
# </div>
# <div class="ESPNLiveTabContent" id="ESPNLiveFoot">
# </div>
# <div class="ESPNLiveTabContent" id="ESPNLiveFootFixt">
# </div>
# </div>
# </div>
# </li>
# <li>
# <h2 class="espnCricket"><span class="liveArrow"></span>Cricket<span class="live-ico"></span></h2>
# <div class="ESPNLive_cont">
# <div class="ESPNLiveTab">
# <ul class="ESPNLiveTabs">
# <li><a class="ESPNLiveTabsOn" href="#ESPNLiveCricResults">Results</a></li>
# <li><a href="#ESPNLiveCric">Today<span id="ESPNLiveCricNo"></span></a></li>
# <li><a href="#ESPNLiveCricFixt">Fixtures</a></li>
# </ul>
# <div class="ESPNLiveTabContent" id="ESPNLiveCricResults">
# </div>
# <div class="ESPNLiveTabContent" id="ESPNLiveCric">
# </div>
# <div class="ESPNLiveTabContent" id="ESPNLiveCricFixt">
# </div>
# </div>
# </div>
# </li>
# <li>
# <h2 class="espnRugby"><span class="liveArrow"></span>Rugby<span class="live-ico"></span></h2>
# <div class="ESPNLive_cont">
# <div class="ESPNLiveTab">
# <ul class="ESPNLiveTabs">
# <li><a class="ESPNLiveTabsOn" href="#ESPNLiveRugResults">Results</a></li>
# <li><a href="#ESPNLiveRug">Today<span id="ESPNLiveRugNo"></span></a></li>
# <li><a href="#ESPNLiveRugFixt">Fixtures</a></li>
# </ul>
# <div class="ESPNLiveTabContent" id="ESPNLiveRugResults">
# </div>
# <div class="ESPNLiveTabContent" id="ESPNLiveRug">
# </div>
# <div class="ESPNLiveTabContent" id="ESPNLiveRugFixt">
# </div>
# </div>
# </div>
# </li>
# <li>
# <div class="live_f1_countdown" data-starttime="2018-11-11 18:10:00" id="countdown">
# <ul>
# <li><span>Days</span><div id="liveDay"></div></li>
# <li><span>Hrs</span><div id="liveHour"></div></li>
# <li><span>Mins</span><div id="liveMin"></div></li>
# <li><span>Secs</span><div id="liveSec"></div></li>
# </ul>
# </div>
# <h2 class="espnF1"><span class="liveArrow"></span>F1 - Brazilian GP</h2>
# <div class="ESPNLive_cont">
# <div class="content-box">
# <div id="race320T"></div>
# <div class="race320M" style="border-top:3px solid #ff0000!important;">
# <div class="featured-driver" style="font-size:0.917em; line-height:150%;">
# <a class="featuredhead" href="/f1/motorsport/race/242246.html?template=home">Brazilian Grand Prix</a>
# <span class="featureddriver">
# November 9-11
# 		</span>
# <div class="frame" style="float:right; width:40%; margin-top:0.5em;">
# <a href="/f1/motorsport/circuit/1296.html"><img alt="Autódromo José Carlos Pace" src="/inline/motorsport/image/3869.jpg?alt=2" title="Interlagos"/></a>
# </div>
# <div class="pglst" style="margin: 0.5em 0 0.5em 0;">
# <strong>November 9: Free practice 1</strong><br/>
# <a href="/f1/motorsport/race/242246.html"><b>Live coverage </b></a>
# <br/>
# <strong>November 9: Free practice 2</strong><br/>
# <a href="/f1/motorsport/race/242246.html"><b>Live coverage </b></a>
# <br/>
# <strong>November 10: Free practice 3</strong><br/>
# <a href="/f1/motorsport/race/242246.html"><b>Live coverage </b></a>
# <br/>
# <strong>November 10: Qualifying</strong><br/>
# <a href="/f1/motorsport/race/242246.html"><b>Live coverage </b></a>
# <br/>
# <strong>November 11: Race</strong><br/>
# 15:10 local | 17:10 GMT<br/> </div>
# <ul>
# <li>
# <a href="/f1/motorsport/race/242246.html?template=home">Race home </a>
# </li>
# <li>
# <a href="/f1/motorsport/race/242246.html?template=live">Live coverage </a>
# </li>
# <li>
# <a href="/f1/motorsport/circuit/1296.html">Circuit profile </a>
# </li>
# </ul>
# </div>
# </div>
# <div id="race320B"></div>
# </div>
# </div>
# </li>
# <li class="ESPNLiveLastOpt">
# <h2 class="espnOther"><span class="liveArrow"></span><span class="espn-logo">ESPN</span>Other<span class="live-ico">Live &gt;&gt;</span></h2>
# <div class="ESPNLive_cont">
#                     Golf - Houston Open<br/>
# Snooker - China Open<br/>
# Tennis - Miami Open
#
#                 </div>
# </li>
# </ul>
# </div>
# <div class="top320"></div>
# <div class="scrumPanelsContent">
# <div id="scrumRhsBgMpu">
# <div class="espni-ad-slot ad-incontent" data-kvpos="top" data-slot-type="incontent"></div>
# </div>
# </div>
# <div class="botom320"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="mboxDefault"></div>
# <script language="JavaScript1.2" type="text/javascript">
#             mboxCreate('scrumGlobal','profile.country=uk');
#         </script>
# <script src="http://i.imgci.com/navigation/cricinfo/ci/assets/js/plugins/jquery.cookie-1.4.1.js"></script>
# <style type="text/css">
#     .cookie-overlay{background-color:rgba(0,0,0,.75);bottom:0;position:fixed;width:100%;padding:25px 0;text-align:center;z-index:9999;display:none;font:16px -apple-system,BlinkMacSystemFont,"Segoe UI",Roboto,Oxygen,Ubuntu,Cantarell,"Fira Sans","Droid Sans","Helvetica Neue",sans-serif}.cookie-overlay h1{font-size:18px;font-weight:600;text-transform:uppercase;margin:0 auto;color:#fff}.cookie-overlay p.message{width:34%;margin:0 auto;padding:5px 0 10px;color:#fff;font-size:14px;line-height:24px}.cookie-overlay p.message a{color:#fff}.cookie-overlay p.message a:hover{color:#439ec9;text-decoration:underline}.cookie-overlay .cookie-continue{display:block;font-size:11px;margin:auto auto 12px;width:384px;max-width:384px;min-width:120px;background-color:#06c;color:#fff;cursor:pointer;border:0;border-radius:40px;line-height:26px;-webkit-transition-duration:.25s;transition-duration:.25s;-webkit-transition-property:all;-moz-transition-property:all;-ms-transition-property:all;-o-transition-property:all;transition-property:all}.cookie-overlay .cookie-continue:hover{background-color:#007aff}.cookie-overlay-buttonWrapper{margin:0 auto;max-width:384px}.cookie-overlay-altBtns .button-alt{border-color:#cbccce;color:#fff;text-transform:none;width:calc(50% - 4px);font-size:11px;height:28px;line-height:26px;padding:0 12px;-webkit-transition-duration:.25s;transition-duration:.25s;-webkit-transition-property:all;-moz-transition-property:all;-ms-transition-property:all;-o-transition-property:all;transition-property:all}.cookie-overlay .cookie-overlay-buttonWrapper .cookie-overlay-altBtns .button-alt:hover{background-color:#6c6d6f;border:1px solid #6c6d6f;color:#fff}@media screen and (min-width:0) and (max-width:768px){.cookie-overlay p.message{font-size:12px;width:82%}}
#     .button-alt,  .button-filter-alt, .btn-social {
#     -webkit-transition-duration: .25s;
#     transition-duration: .25s;
#     -webkit-transition-property: all;
#     -moz-transition-property: all;
#     -ms-transition-property: all;
#     -o-transition-property: all;
#     transition-property: all;
#     display: -webkit-inline-box;
#     display: -webkit-inline-flex;
#     display: -moz-inline-flex;
#     display: -ms-inline-flexbox;
#     display: inline-flex;
#     -webkit-box-pack: center;
#     -ms-flex-pack: center;
#     -webkit-justify-content: center;
#     -moz-justify-content: center;
#     justify-content: center;
#     -webkit-box-align: center;
#     -ms-flex-align: center;
#     -webkit-align-items: center;
#     -moz-align-items: center;
#     align-items: center;
#     *background-color: #007aff;
#     background-image: linear-gradient(124deg, transparent 24%, rgba(0,0,0,0.25) 76%);
#     background-repeat: no-repeat;
#     border: 1px transparent solid;
#     border-radius: 40px;
#     box-shadow: inset 0px 0px 0px 0px rgba(21,22,23,0);
#     color: #fff;
#     cursor: pointer;
#     font-family: -apple-system,BlinkMacSystemFont,"Segoe UI","Roboto","Oxygen","Ubuntu","Cantarell","Fira Sans","Droid Sans","Helvetica Neue",sans-serif;
#     font-size: 12px;
#     font-weight: 400;
#     height: 32px;
#     line-height: 30px;
#     max-width: 414px;
#     outline: none;
#     overflow: hidden;
#     padding: 0 18px;
#     position: relative;
#     text-align: center;
#     text-overflow: ellipsis;
#     white-space: nowrap;
# }
# *, *:after, *:before {
#     -webkit-box-sizing: border-box;
#     -moz-box-sizing: border-box;
#     -ms-box-sizing: border-box;
#     -o-box-sizing: border-box;
#     box-sizing: border-box;
# }
#     </style>
# <div class="cookie-overlay">
# <h1>ABOUT COOKIES</h1>
# <p class="message">
#           To help make this website better, to improve and personalize your experience and for advertising purposes, are you happy to accept cookies and other technologies.
#         </p>
# <div class="cookie-overlay-buttonWrapper">
# <button class="cookie-continue">YES</button>
# <div class="cookie-overlay-altBtns">
# <a class="button-alt sm" href="https://privacy.thewaltdisneycompany.com/en/current-privacy-policy/cookies-policy/" target="_blank">More Info Here</a>
# <a class="button-alt sm" href="https://preferences-mgr.truste.com/?pid=disney01&amp;aid=espnemea01&amp;type=espnemea" target="_blank">Cookie Choices</a>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#
#       /**
#        * Should cookie message get displayed for this cluster?
#        * @return {boolean} true if cookie message needs to be shown else false
#        */
#       function __validateCookieClusters(){
#         var location_country = 'gb';
#         var location_cluster = 'uk';
#         var __isUKCluster = (location_cluster == 'uk') ? true : false
#         var __isEuroCluster = (location_cluster == 'eur') ? true : false
#         var __countryArr = ["at","be","bg","hr","cy","cz","dk","ee","fi","fr",
#                             "de","gr","hu","ie","it","lv","lt","lu","mt","nl",
#                             "pl","pt","ro","sk","si","es","se", "gb"];
#
#         // Show cookie message only for uk and other eu countries
#         var showCookieMessage = __isUKCluster || (__isEuroCluster && (__countryArr.indexOf(location_country) > -1) )
#         return showCookieMessage;
#       }
#
#       /**
#        * Display cookie message for specified clusters
#        */
#       function __displayCookie(){
#         // Check if jQuery is present on page else return
#         if (typeof $ === 'undefined') {
#           return
#         }
#
#         if($.cookie('about_cookie') == "1"){
#             $(".cookie-overlay").hide();
#         }else{
#             $(".cookie-overlay").show();
#         }
#
#         $(".cookie-continue").on("click", function(){
#             //var __expireTime = new Date;
#             //__expireTime.setFullYear(__expireTime.getFullYear( ) +1);
#             //$.cookie('about_cookie', '1', {expires: __expireTime, path:'/', domain:'.espncricinfo.com'});
#
#             // Cookie expiry time set to 1 year
#             var domainPath = window.location ? window.location.hostname : ''
#             $.cookie('about_cookie', '1', {expires: 365, path:'/', domain:domainPath});
#             $(".cookie-overlay").hide();
#         })
#       }
#
#       if (typeof jQuery !== 'undefined') {
#         // Setup on ready callback only for specified clusters
#         if (__validateCookieClusters() === true) {
#           $(document).ready(__displayCookie);
#         }
#       }
#
#     </script>
# <script src="http://content.dl-rms.com/rms/mother/38223/nodetag.js" type="text/javascript"></script>
# <script type="text/javascript">
#     var _sf_async_config={};
#     /** CONFIGURATION START **/
#     _sf_async_config.uid = 26455;
#     _sf_async_config.domain = 'espnscrum.com';
#     _sf_async_config.useCanonical = true;
#     _sf_async_config.sections = 'rugby,Players';
#     /** CONFIGURATION END **/
#     (function(){
#       function loadChartbeat() {
#         window._sf_endpt=(new Date()).getTime();
#         var e = document.createElement('script');
#         e.setAttribute('language', 'javascript');
#         e.setAttribute('type', 'text/javascript');
#         e.setAttribute('src',
#            (('https:' == document.location.protocol) ? 'https://a248.e.akamai.net/chartbeat.download.akamai.com/102508/' : 'http://static.chartbeat.com/') +
#            'js/chartbeat.js');
#         document.body.appendChild(e);
#       }
#       var oldonload = window.onload;
#       window.onload = (typeof window.onload != 'function') ?
#       loadChartbeat : function() { oldonload(); loadChartbeat(); };
#     })();
# </script>
# <!-- Begin comScore Tag -->
# <script>
# var _comscore = _comscore || [];
# _comscore.push({ c1: "2", c2: "3000005" });
# (function() {
# var s = document.createElement("script"), el =
# document.getElementsByTagName("script")[0]; s.async = true;
# s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
# el.parentNode.insertBefore(s, el);
# })();
# </script>
# <!-- End comScore Tag -->
# <!--
# New implementation	:	01st Oct 2008
#
# SiteCatalyst code version: H.15.1
# Copyright 1997-2007 Omniture, Inc. More info available at
# http://www.omniture.com -->
# <script language="JavaScript" type="text/javascript">
#
# 	var s_account = "wdgespcouk";
#
# </script>
# <script language="javascript" src="http://www.espnscrum.com/navigation/scrum/omniture/scrum_omnitureGlobal.js" type="text/javascript"></script>
# <script>
# <!--
# /* You may give each page an identifying name, server, and channel on the next lines. */
#
#
# if (typeof scrumTitle == 'undefined'){
# 	s_omni.pageName = "scrum:" + document.title; //Omniture Page Name(S)
# }
# else{
# 	s_omni.pageName = "scrum:" + scrumTitle; //Omniture Page Name(S)
# }
#
#
# //alert(s_omni.pageName);
#
# s_omni.server=window.location.host; // Server from the Host
#
# s_omni.prop1 = "espnuk";
#
# var omniPath = location.pathname;
# //alert(omniPath);
#
# if (typeof scrumSiteSection1 != 'undefined'){
#
# 	s_omni.channel = "scrum";
#
# }
#
# //alert(s_omni.channel);
#
# //Error page variables
# if(typeof omniPageType == 'undefined'){
# 	s_omni.pageType = "";
# }
# else{
# 	s_omni.pageType = "errorPage";
# 	s_omni.pageName = "";
# 	s_omni.server = "";
# 	s_omni.prop1 = "";
# }
#
# if (typeof scrumOmniContent != 'undefined'){
# 	s_omni.prop4 = scrumOmniContent.toLowerCase();
# }
#
# if (typeof scrumSiteSection2 != 'undefined'){
#
# 	scrumSiteSection2 = scrumSiteSection1;
#
# 	s_omni.prop5 = s_omni.channel + ":"+ scrumSiteSection2.toLowerCase()
# }
#
# if(typeof scrumStoryId != 'undefined'){
# 	s_omni.prop15 = s_omni.eVar20 = scrumStoryId; //Story Object id
# }
#
# //s_omni.prop16 = s_omni.eVar12 = cqanswer //Country where the page is viewed and eVar12 //set on success page returned after engaging with interactions like voting on polls and making entries on story conversation pages - Engagement Id
# s_omni.prop17 = s_omni.eVar9 = "en" // Language Code
#
# if(typeof scrumAuthId != 'undefined'){
# 	s_omni.prop23 = s_omni.eVar10 = scrumAuthId; //Columnist id
# }
#
# s_omni.prop25 = s_omni.eVar19 = "rugby" // Sport
#
# //s_omni.hier1 = s_omni.prop5 ":" + s_omni.pageName ; //Content Hierarchy
# s_omni.hier1 = s_omni.pageName; //Content Hierarchy
#
# if(typeof scrumIST != 'undefined'){
# 	s_omni.eVar5 = scrumIST; //Internal Search type
# }
#
# s_omni.eVar13 = s_omni.prop1 + ":" + s_omni.pageName //Page name
#
# if(typeof scrumSearch != 'undefined' && scrumSearch != ""){
#     //alert(scrumSearch);
# 	s_omni.prop7 = scrumSearch;
# 	s_omni.prop7 = s_omni.prop7.toLowerCase();
# }
# if( typeof omniMVO != 'undefined'){
# 	s_omni.prop32 = omniMVO;
# }
#
# /************* DO NOT ALTER ANYTHING BELOW THIS LINE ! **************/
# var s_code=s_omni.t();if(s_code)document.write(s_code)//-->
#
# </script>
# <!-- End SiteCatalyst code version: H.14. -->
# <!-- Init and load GPT -->
# <script src="http://www.espnscrum.com/navigation/scrum/scrum.gpt.1.0.0.min.js?v=2" type="text/javascript"></script>
# </body>
# </html>

# %%
# 下記を参考にまずは、腕試し。
# https://qiita.com/Azunyan1111/items/9b3d16428d2bcc7c9406
html = urllib.request.urlopen(url)

# htmlをBeautifulSoupで扱う
soup = bs4.BeautifulSoup(html, "html.parser")

# タイトル要素を取得する → <title>経済、株価、ビジネス、政治のニュース:日経電子版</title>
title_tag = soup.title

# 要素の文字列を取得する → 経済、株価、ビジネス、政治のニュース:日経電子版
title = title_tag.string

# タイトル要素を出力
print(title_tag)

# タイトルを文字列を出力
print(title)
# Out:
# <title>Rugby Union | New Zealand Caps | ESPN Scrum</title>
# Rugby Union | New Zealand Caps | ESPN Scrum

# %%
# 手っ取り早く集めたいので、
# aタグを集める
# hrefの値がニュージーランドの選手のリンクか取得
# 配列に格納
# 配列を改行コードでjoinして保存

tags = soup.find_all("a")

